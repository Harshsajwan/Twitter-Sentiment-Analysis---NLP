# %% [markdown]
# ## Dataset Information
#
# The objective of this task is to detect hate speech in tweets. For the sake of simplicity, we say a tweet contains hate speech if it has a racist or sexist sentiment associated with it. So, the task is to classify racist or sexist tweets from other tweets.
#
# Formally, given a training sample of tweets and labels, where label '1' denotes the tweet is racist/sexist and label '0' denotes the tweet is not racist/sexist, your objective is to predict the labels on the test dataset.
#
# For training the models, we provide a labelled dataset of 31,962 tweets. The dataset is provided in the form of a csv file with each line storing a tweet id, its label and the tweet.

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk
import warnings
# %matplotlib inline

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('Twitter Sentiments.csv')
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
# datatype info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      31962 non-null  int64
#  1   label   31962 non-null  int64
#  2   tweet   31962 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB

# %% [markdown]
# ## Preprocessing the dataset

# %%
# removes pattern in the input text
import re
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for word in r:
        input_txt = re.sub(word, "", input_txt)
    return input_txt

# %%
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
# remove twitter handles (@user)
df['clean_tweet'] = np.vectorize(remove_pattern)(df['tweet'], "@[\w]*")

# %%
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...  \
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0    when a father is dysfunctional and is so sel...
# 1    thanks for #lyft credit i can't use cause th...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation

# %%
# remove special characters, numbers and punctuations
df['clean_tweet'] = df['clean_tweet'].str.replace("[^a-zA-Z#]", " ")
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...  \
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0    when a father is dysfunctional and is so sel...
# 1    thanks for #lyft credit i can't use cause th...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation

# %%
# remove short words
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: " ".join([w for w in x.split() if len(w)>3]))
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...  \
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0  when father dysfunctional selfish drags kids i...
# 1  thanks #lyft credit can't cause they don't off...
# 2                                bihday your majesty
# 3  #model love take with time urð±!!! ððð...
# 4                    factsguide: society #motivation

# %%
# individual words considered as tokens
tokenized_tweet = df['clean_tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [when, father, dysfunctional, selfish, drags, ...
# 1    [thanks, #lyft, credit, can't, cause, they, do...
# 2                              [bihday, your, majesty]
# 3    [#model, love, take, with, time, urð±!!!, ð...
# 4                  [factsguide:, society, #motivation]
# Name: clean_tweet, dtype: object

# %%
# stem the words
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda sentence: [stemmer.stem(word) for word in sentence])
tokenized_tweet.head()
# Out:
# 0    [when, father, dysfunct, selfish, drag, kid, i...
# 1    [thank, #lyft, credit, can't, caus, they, don'...
# 2                              [bihday, your, majesti]
# 3    [#model, love, take, with, time, urð±!!!, ð...
# 4                       [factsguide:, societi, #motiv]
# Name: clean_tweet, dtype: object

# %%
# combine words into single sentence
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = " ".join(tokenized_tweet[i])
    
df['clean_tweet'] = tokenized_tweet
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...  \
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0  when father dysfunct selfish drag kid into dys...
# 1  thank #lyft credit can't caus they don't offer...
# 2                                bihday your majesti
# 3  #model love take with time urð±!!! ððð...
# 4                         factsguide: societi #motiv

# %% [markdown]
# ## Exploratory Data Analysis

# %%
 #!pip install wordcloud

# %%
# visualize the frequent words
all_words = " ".join([sentence for sentence in df['clean_tweet']])

from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# frequent words visualization for +ve
all_words = " ".join([sentence for sentence in df['clean_tweet'][df['label']==0]])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# frequent words visualization for -ve
all_words = " ".join([sentence for sentence in df['clean_tweet'][df['label']==1]])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# extract the hashtag
def hashtag_extract(tweets):
    hashtags = []
    # loop words in the tweet
    for tweet in tweets:
        ht = re.findall(r"#(\w+)", tweet)
        hashtags.append(ht)
    return hashtags

# %%
# extract hashtags from non-racist/sexist tweets
ht_positive = hashtag_extract(df['clean_tweet'][df['label']==0])

# extract hashtags from racist/sexist tweets
ht_negative = hashtag_extract(df['clean_tweet'][df['label']==1])

# %%
ht_positive[:5]
# Out:
# [['run'], ['lyft', 'disapoint', 'getthank'], [], ['model'], ['motiv']]

# %%
# unnest list
ht_positive = sum([ht_positive], [])
ht_negative = sum([ht_negative], [])

# %%
ht_positive[:5]
# Out:
# [['run'], ['lyft', 'disapoint', 'getthank'], [], ['model'], ['motiv']]

# %%
ht_positive_flattened = [tag for sublist in ht_positive for tag in sublist]
freq = nltk.FreqDist(ht_positive_flattened)
d = pd.DataFrame({'Hashtag': list(freq.keys()), 'Count': list(freq.values())})
d.head()
# Out:
#      Hashtag  Count
# 0        run     70
# 1       lyft      2
# 2  disapoint      1
# 3   getthank      2
# 4      model    374

# %%
# select top 10 hashtags
d = d.nlargest(columns='Count', n=10)
plt.figure(figsize=(15,9))
sns.barplot(data=d, x='Hashtag', y='Count')
plt.show()

# %%
ht_negative_flattened = [tag for sublist in ht_negative for tag in sublist]
freq = nltk.FreqDist(ht_negative_flattened)
d = pd.DataFrame({'Hashtag': list(freq.keys()), 'Count': list(freq.values())})
d.head()
# Out:
#         Hashtag  Count
# 0           cnn      9
# 1      michigan      2
# 2          tcot     14
# 3     australia      6
# 4  opkillingbay      2

# %%
# select top 10 hashtags
d = d.nlargest(columns='Count', n=10)
plt.figure(figsize=(15,9))
sns.barplot(data=d, x='Hashtag', y='Count')
plt.show()

# %% [markdown]
# ## Input Split

# %%
# feature extraction
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
bow = bow_vectorizer.fit_transform(df['clean_tweet'])

# %%
#pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(bow, df['label'], random_state=42, test_size=0.25)
# Out:
# <7991x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31272 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score

# %%
# training
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# testing
pred = model.predict(x_test)
f1_score(y_test, pred)
# Out:
# 0.5083135391923991

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9481917156801402

# %%
# use probability to get output
pred_prob = model.predict_proba(x_test)
pred = pred_prob[:, 1] >= 0.3
pred = pred.astype(np.int)

f1_score(y_test, pred)
# Out:
# 0.560856864654333

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9435615066950319

# %%
pred_prob[0][1] >= 0.3
# Out:
# False

# %%
# Determine sentiment based on predicted labels
predicted_sentiment = ['negative' if label == 0 else 'positive' for label in pred]

# %%
for sentiment, text in zip(predicted_sentiment, df['clean_tweet']):
    print(f"Sentiment: {sentiment}, Text: {text}")
# Out:
# Sentiment: negative, Text: when father dysfunct selfish drag kid into dysfunction. #run
# Sentiment: negative, Text: thank #lyft credit can't caus they don't offer wheelchair van pdx. #disapoint #getthank
# Sentiment: negative, Text: bihday your majesti
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: factsguide: societi #motiv
# Sentiment: negative, Text: [2/2] huge fare talk befor they leave. chao disput when they there. #allshowandnogo
# Sentiment: negative, Text: camp tomorrow dannyâ¦
# Sentiment: negative, Text: next school year year exams.ð¯ can't think about that ð­ #school #exam #hate #imagin #actorslif #revolutionschool #girl
# Sentiment: negative, Text: won!!! love land!!! #allin #cav #champion #cleveland #clevelandcavali
# Sentiment: negative, Text: welcom here it' #gr8
# Sentiment: negative, Text: #ireland consum price index (mom) climb from previou 0.2% 0.5% #blog #silver #gold #forex
# Sentiment: negative, Text: selfish. #orlando #standwithorlando #pulseshoot #orlandoshoot #biggerproblem #selfish #heabreak #valu #love
# Sentiment: negative, Text: daddi today!! #80day #gettingf
# Sentiment: negative, Text: #cnn call #michigan middl school 'build wall' chant #tcot
# Sentiment: negative, Text: comment! #australia #opkillingbay #seashepherd #helpcovedolphin #thecov #helpcovedolphin
# Sentiment: negative, Text: ouch...junior angryð#got7 #junior #yugyoem #omg
# Sentiment: negative, Text: thank have paner. #thank #posit
# Sentiment: negative, Text: retweet agree!
# Sentiment: negative, Text: #friday! ð smile around user: #cooki make peopl
# Sentiment: negative, Text: know, essenti oil made chemicals.
# Sentiment: negative, Text: #euro2016 peopl blame conced goal rooney gave away free kick know bale them from there.
# Sentiment: negative, Text: littl dude.. #badday #coneofsham #cat #piss #funni #laugh
# Sentiment: negative, Text: product day: happi #wine tool who' it' #weekend? time open &amp; drink
# Sentiment: negative, Text: lumpi say prove lumpy.
# Sentiment: negative, Text: #tgif #gamedev #indiedev #indiegamedev #squad!
# Sentiment: negative, Text: beauti sign vendor $45.00!! #upsideofflorida #shopalyssa #love
# Sentiment: negative, Text: #smile when #media ðð #pressconfer #antalya #turkey sunday #throwback love! ððâ¤ï¸
# Sentiment: negative, Text: great panel mediat public servic #ica16
# Sentiment: negative, Text: happi father' ðððð
# Sentiment: negative, Text: peopl went nightclub have good night man' action mean those peopl lost their famili forev #rip#orlando
# Sentiment: negative, Text: have never chanc vote presidenti candid excit about thi cycl look different.
# Sentiment: negative, Text: #alohafriday #time doe #not #exist #positivevib #hawaiian
# Sentiment: negative, Text: fellow nohern ireland sadley pass away tonight!.. gawa, forev sing cheer fire
# Sentiment: negative, Text: hard monday cloudi weather. disabl oxygen product today. #goodnight #badmonday
# Sentiment: negative, Text: it' unbeliev that 21st centuri we'd need someth like this. again. #neverump #xenophobia
# Sentiment: negative, Text: #taylorswift1989 bull will domin your bull will direct whatev want
# Sentiment: negative, Text: morning~~ #travelingram #dalat #ripinkylif
# Sentiment: negative, Text: onc more onli word tell all: #photoshop. #enoughisenough #dontphotoshopeveryth #wheresallthenaturalphoto
# Sentiment: negative, Text: #cedarpoint. wait hour valravn line stop working. were close.
# Sentiment: negative, Text: thank sunshine. #thank #posit
# Sentiment: negative, Text: when final finish book you'v been work awhile... #bookworm #ontothenextnovel
# Sentiment: negative, Text: yup, be knick hard, easier just when playoff roll around ð
# Sentiment: negative, Text: there life after social networking. embrac each day.
# Sentiment: negative, Text: share same bihday bihday snake! thi weekend ðð¼
# Sentiment: negative, Text: love echeveria blooms#flow #grow #garden #iphonesia #bliss #bloom #basilicabotanica
# Sentiment: negative, Text: amazing. #i_am #posit #affirm
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: #whenev #someth goe #wrong
# Sentiment: positive, Text: feel blue #illustr
# Sentiment: negative, Text: best about life know are! ðâï¸ð¼ð»
# Sentiment: negative, Text: #abc2020 get readi remov victum #pulseclub #prayfororlando
# Sentiment: negative, Text: #bihday #nose #job ðð¶ððð #bihday #petunia love ð
# Sentiment: negative, Text: concelebr #albanpilgrimag first time.
# Sentiment: negative, Text: scum-baggeri begin.....
# Sentiment: negative, Text: thank you! ðð super love â¤ï¸ zpamdelacruz #wedding# dolores, capa tarlac.
# Sentiment: negative, Text: scourg those play baroqu piec piano beyond belief
# Sentiment: negative, Text: let fight against #love #peac
# Sentiment: negative, Text: happi fatherâ day, rayo #video #father #day #rayo #world #hotvideo #video
# Sentiment: negative, Text: ascot time with thi babe â¤ï¸â¤ï¸ #ascot #fashion #monochrom #style #instahappyday
# Sentiment: negative, Text: weekend..i here!!ððððð #selfi #yolo #xoxo #like4lik
# Sentiment: negative, Text: happi work conference: right' mindset lead culture-of-develop organ #work #mindset
# Sentiment: negative, Text: christina grimmie' last perform befor be shot... #christinarip #voic #christinagrimmi
# Sentiment: negative, Text: readi danc #roar #preschool #student #proudâ¦
# Sentiment: negative, Text: you'v realli feel
# Sentiment: negative, Text: wife whom ador miss your poland show becaus surgery. name bridget &amp; she' everything.
# Sentiment: positive, Text: jealou right now.... #chatiado
# Sentiment: negative, Text: celebr everi that play it' fatherli role. father' day#
# Sentiment: negative, Text: sure they just happy.... ðð½ðð½ðð½ hour
# Sentiment: negative, Text: ð©the white establish can't have folx run around love themselv promot great
# Sentiment: negative, Text: good morning! journey begins! ððð»ð³ #travel #yeah #thejourneybegin #helloâ¦
# Sentiment: negative, Text: #luv #hottweet like thi from â¥#venusexchangeâ¥
# Sentiment: negative, Text: brochur have arrived! exciting!! #awork #solut
# Sentiment: negative, Text: much stuff happen florida! first #orlando shoot #disneygatorattack year kidð¥ð
# Sentiment: negative, Text: ferrari will itðªð¼ sake championship. thi clearli turn point ferrari,mercs...ð
# Sentiment: negative, Text: ace first test! #proud
# Sentiment: negative, Text: seek probe into #udtapunjab' leak, point finger #amarinder, #aap
# Sentiment: negative, Text: wrap #senseaboutmath
# Sentiment: negative, Text: hey, white people: call peopl 'white' #race #ident #medâ¦
# Sentiment: negative, Text: might just have shown here today. regurgit talk point name calling?
# Sentiment: negative, Text: sometim have rais brow rais bar. #golfstrengthandcondit #strong #felixfoisgolf
# Sentiment: negative, Text: about that ððð #greathonour #careerconvo
# Sentiment: negative, Text: design #innov learn space includ #wateringhol #cave #mountaintop #campfir hâ¦
# Sentiment: negative, Text: #altright use &amp; insecur lure into #whitesupremaci
# Sentiment: negative, Text: carri wouldn't help can't take with you. control won't stop black market! terror will worse!
# Sentiment: negative, Text: power your mind #heal your body!! #altwaystoh #healthi #peace!
# Sentiment: positive, Text: woohoo!! just over week
# Sentiment: negative, Text: be away place where have famili member
# Sentiment: negative, Text: readi rehears tonight with music videos, look announcement! #midweek #newmus #watchthisspac #guitar
# Sentiment: negative, Text: monday night channel!!!! final what fuss about!!!
# Sentiment: negative, Text: watch episod
# Sentiment: negative, Text: offlin after veri nice long night.. ð #snapchat #redhead #vermillionr
# Sentiment: negative, Text: thing incred #peopl
# Sentiment: negative, Text: yes! receiv accept letter master will back again october! #goodtim #histori
# Sentiment: negative, Text: daughter ride bike around driveway, play guitar while enjoy ðº campfire... #summeim #memori
# Sentiment: negative, Text: omg!!! love thi station!!! work!!! while get work done course!!!! #memori
# Sentiment: negative, Text: i'll alway hope that i'll you, don't think that it' gonna happen anytim soon...
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: coupl have nake japanes girl
# Sentiment: negative, Text: #hump that #hump #humpersð© edwardsville, pennsylvania
# Sentiment: negative, Text: personalis we... 7.99 here: #shop #cool #home #fun
# Sentiment: negative, Text: there some truli sick there.
# Sentiment: negative, Text: trump call obama resign over orlando shootings? point. year "talk" about change.
# Sentiment: negative, Text: long now!!! #nashvilletour2016 #nashvilleforev ððð
# Sentiment: negative, Text: #eur/usd clear 1.1400 barrier, jump fresh 4-week high #blog #silver #gold #forex
# Sentiment: negative, Text: go tomorrow!!!
# Sentiment: negative, Text: thank good friends. #thank #posit
# Sentiment: negative, Text: still wrap head around fact that #christinagrimmi gone. fact that destroy #prayfororlando just
# Sentiment: negative, Text: just receiv from can't wait bake #eyelid .ðððððð ðððâ¦
# Sentiment: negative, Text: were play #vigilfororlando #harp #clonakilti #rip
# Sentiment: positive, Text: #ihavenofriend #someonecomewithm
# Sentiment: negative, Text: sunday...ð #weekend #relax #icon #woman #sundaymorn #sunday #marilynmonro
# Sentiment: negative, Text: interest #linguist that doesn't address #race &amp; racism about #power. #raciolinguist bringsâ¦
# Sentiment: negative, Text: belov long lost cds, recov thank appl music.
# Sentiment: negative, Text: #marvel #song #musica #weed #ripchristina #adel #danc (vine
# Sentiment: negative, Text: mock obama be black. #brexit
# Sentiment: negative, Text: #under spell brexit referendum commerzbank #blog #silver #gold #forex
# Sentiment: positive, Text: amaz health benefit cucumbers! #healthi #altwaystoheal!
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: work ðªð»ð¶ð¼ #ofw #pinoy #followm #iger #instagood #smile #love
# Sentiment: negative, Text: #toradora #anim #animeedit made #breakup #alon #lone
# Sentiment: negative, Text: lap pool, ride done pick membership form
# Sentiment: positive, Text: #cotd polar bear climb racing: angri polar bear climb racing, polar bear live cold place look
# Sentiment: negative, Text: get angry. muslim assassin much.
# Sentiment: negative, Text: happi snappi ðð¼ wait footbal #footbal #snapchat
# Sentiment: negative, Text: friday miss you!! #fringes#qcbags#summ ððððððó¾®ð»
# Sentiment: positive, Text: #nochebuena #lasvega #usa vega strip
# Sentiment: negative, Text: fleurett ð¯ð #instaboy#instaman#sefie#septum#friend #smiles#blackandwhit
# Sentiment: negative, Text: branch itâ just raini write tear fli bird #haiku #3line #micropoetri
# Sentiment: negative, Text: yeah! button mail ð they pretty! #jewelrymak #button
# Sentiment: negative, Text: driver femal moos river #weston. moos killed. driver crew remov anim
# Sentiment: negative, Text: afterpas. made japan. ï¼madeinjapan #eo ï¼cute #fun #cawaii #love #strawberri #tomato
# Sentiment: negative, Text: #peopl aren't protest #trump becaus #republican won-they becaus trump fuher &amp;â¦
# Sentiment: negative, Text: need find spend time alway mind. #boy #guy
# Sentiment: negative, Text: [1466047260.15] updat #social #analyt #photooftheday #iger #like
# Sentiment: negative, Text: anyon know date #doj #fbi becam corrupted? #emailg #hillary2016 #shame #disgrac #ridicul
# Sentiment: positive, Text: #stupid make more than even #negligence.whi #sachintendulkar instal were go take off?
# Sentiment: negative, Text: ððððâ¨â­ï¸ #ãããã bihdayð #21thbihday ð #bestfriend ð #loveð¼
# Sentiment: negative, Text: ð most impoant thing #enjoy your life itâ that matters. life sho. #pooh4u
# Sentiment: negative, Text: happi bihday chri evansððððððð great actor human ððð³ðð»ð¸ððð #chrisevan #bihdayâ¦
# Sentiment: negative, Text: heas, thoughts, prayer more than peopl were murder nightclub #florida
# Sentiment: negative, Text: demo guitar album #newalbum #indi #guitar #echobelli
# Sentiment: negative, Text: retweet lion #tgif #webmaret #seo #commun #manag #weekend...
# Sentiment: negative, Text: #nzd/usd: target week 0.7190 #blog #silver #gold #forex
# Sentiment: negative, Text: i'v pretti bihday week before, thi worst ever. ð #bihdayweeksuck #bithday27 #tâ¦
# Sentiment: negative, Text: bless have work with sa' best lead ladiesðð
# Sentiment: negative, Text: happiest place ð« #disneysmagickingdom #disney #magickingdom #disneyland #orlandoâ¦
# Sentiment: negative, Text: kinda among human again.
# Sentiment: negative, Text: just found after been exclaim blain' hair other nite. ð­
# Sentiment: negative, Text: &lt;3 listen most beauti best friend sing with most amaz voic &lt;3 &lt;3 &lt;3 &lt;3
# Sentiment: negative, Text: #healthi freedom from effo present mere mean that there been effo store past. theodor rooseveltâ¦
# Sentiment: negative, Text: when know yall aint go know where #love #commit #trust #faith
# Sentiment: negative, Text: it' when call #michelleobama gorilla becaus racist have long thought black peopl betâ¦
# Sentiment: negative, Text: #newarkfestiv thi thi year wait show year run
# Sentiment: negative, Text: when internet broken can't watch netflix. #mochithepug #puglif
# Sentiment: negative, Text: will just that....then what..busi usual.
# Sentiment: negative, Text: thi dick suckin tequila lovin slut, wouldnt want other ðð #justalil #butstillontim
# Sentiment: negative, Text: smaller hand show, barri probabl lie about be #knick game suck more than #golfâ¦
# Sentiment: negative, Text: good morn friday! what everyon do thi weekend? #goodmorn #friday #girl #love #florida
# Sentiment: positive, Text: challeng #aap' claim that #punjabi #drugaddicts, dare prove
# Sentiment: negative, Text: #tracerequest send deepest condol orlando families. zimbabw commun #touch
# Sentiment: negative, Text: selfi \â¤.â¤/ #guy #mato #chapon
# Sentiment: negative, Text: saturday afternoon meet #friend
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: so &amp; bolts. #bloke
# Sentiment: negative, Text: yeah it' good bing bong bing bong
# Sentiment: negative, Text: just dawn month will see live. excit ððð #vfest #summer
# Sentiment: negative, Text: happi 35th bihday shane robe watson!! #bihday #shane #watson #australia #cricker
# Sentiment: negative, Text: point finger million point right back you, #jewishsupremacist
# Sentiment: negative, Text: hear announc that have move player lead" #whoknows!
# Sentiment: negative, Text: #radio1 go #coldplay tonight yes.
# Sentiment: negative, Text: think like thi too? come through keep
# Sentiment: negative, Text: terrorist constitut rights? thi just anoth excus republican appeas with control measures.
# Sentiment: negative, Text: it' about #gloucesterrugbi
# Sentiment: negative, Text: veri sad, what happened?
# Sentiment: negative, Text: everyon everyth #sad #togeth #alon #down #fine #dandi #lone #exuber #depress #halfful #halfempti
# Sentiment: negative, Text: #mikeashley #sposdirectsham perhaps good exampl need protect #workersright from within europe. #euref #remain
# Sentiment: negative, Text: angri bird stella princess #bird #stella #bad #princess birdsstellabadprincess. time post: wedâ¦
# Sentiment: negative, Text: check incred have made great memori with great peopl
# Sentiment: negative, Text: last night that said "rip when cared" #realli
# Sentiment: negative, Text: hilarious, alreadi block ask one, paicularli difficult, question.
# Sentiment: negative, Text: devast news. goe victim their families. #orlando #heabreak
# Sentiment: negative, Text: "happi state arriv manner traveling." margaret #runbeck #happi #quot #inspir
# Sentiment: negative, Text: safe way heal your #acne!! #altwaystoh #healthi #healing!!
# Sentiment: negative, Text: what creat right now. #beat #makingbeat #thursday #work #istandard #akaiproâ¦
# Sentiment: negative, Text: wed number ðððððð¾ð¾ #wed #weddingpay #love #forev #weddingdressâ¦
# Sentiment: negative, Text: we'r look forward attend cipd ireland confer &amp; workshop #cpd #onemoreday
# Sentiment: negative, Text: final reach follow #twitch. follow hypu #stream tomorrow!
# Sentiment: negative, Text: word free, it' that cost you! #verbal #abus #love #adult #teen
# Sentiment: negative, Text: after what countri went through thi last year peopl bring "bomb" stadium &amp; come here everyth footbal
# Sentiment: negative, Text: thank cats. #thank #posit
# Sentiment: negative, Text: time with swalscha ðâ¨ð #dejeun #lunch #happi #love #amoureuxâ¦
# Sentiment: negative, Text: ilovethesecret #lawofattract #quiz #love #happi #motiv #success #joy #lifeâ¦
# Sentiment: negative, Text: might libtard if... #libtard #sjw #liber #polit
# Sentiment: negative, Text: it' about down... #pole #bgp #rozthediva #blackgirlspol #bodyandpol #live #love
# Sentiment: negative, Text: #argentina2015 attack bull game realli think that head empti around city. each side
# Sentiment: negative, Text: what self-serv hypocrite! alway keep your bounc ball with thi nimrod president.
# Sentiment: negative, Text: #nohcarolina bull will domin your bull will direct whatev want
# Sentiment: negative, Text: #build polar bear climb racing: angri polar bear climb racing, polar bear live cold place
# Sentiment: negative, Text: they want reelect money. #ksleg
# Sentiment: negative, Text: with #orlando right now. truli cannot imagine. could have easili happen anywhere.
# Sentiment: negative, Text: alreemgroup #aly_alshahawi #cute #summer #photographerdubai #sun #hair #mydubaiâ¦
# Sentiment: negative, Text: seem like onli place with action here montreal
# Sentiment: negative, Text: that, wash
# Sentiment: negative, Text: spirited. #i_am #posit #affirm
# Sentiment: positive, Text: thank enteainment. #thank #posit
# Sentiment: negative, Text: thi show truli brisban
# Sentiment: negative, Text: can't wait #wimbledon2016
# Sentiment: negative, Text: happi man!!! #success #model #entrepreneur #speaker #fresh #confid #fashionâ¦
# Sentiment: negative, Text: #gala moment #day #kid #bipolar #frikiegirl2016 lucki chinatown mall, binondo,â¦
# Sentiment: negative, Text: thi realli take piss. angry. just goe show valu isn't. complet utter moron.
# Sentiment: negative, Text: take #trash america... vote against #hate vote against vote against votâ¦
# Sentiment: negative, Text: father #amaz #dad there that give much their families! #enjoy your...
# Sentiment: negative, Text: doe #magnettherapi realli work? #altwaystoh #heal #healthi
# Sentiment: negative, Text: sebbo said all!
# Sentiment: negative, Text: ðððâ¤ï¸ egãï¼ï¼ï¼ smile!!!!!â¤ï¸ð£ð¤ð½ #smile#egsmil #torio
# Sentiment: negative, Text: brilliant servic your ketter branch today custom
# Sentiment: negative, Text: will here screening. will miss will sing song from potp shock treatment, becaus can.
# Sentiment: negative, Text: toraya #bu #alamindah #white #music #carrieunderwood
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: good beer bridpo food &amp; beer fest. back campsit drunk starstruck &amp; move
# Sentiment: negative, Text: ð repost from #propey #ocean #summer #life #famili sydneyâ¦
# Sentiment: negative, Text: want teach love like you'v never felt before. #quot #quot #love #pakistan #allin216 #girl #boy #fashion #feel
# Sentiment: negative, Text: thank now. #thank #posit
# Sentiment: negative, Text: just day left!! #countdown #nolefam can't wait come milan! #22092016 ðð
# Sentiment: negative, Text: stone rose done. time club. day
# Sentiment: negative, Text: "there' reason peopl stay together, they give each other someth nobodi els can." hopelli great
# Sentiment: negative, Text: never know might have crush you! #wakow #buzz #moment #ride #love #crush #date #hookup #app
# Sentiment: negative, Text: friend just engag ð©ââ¤ï¸âðâð©
# Sentiment: negative, Text: day classez #risay18 #risaypl
# Sentiment: positive, Text: #thursday ð watch what need saidâ¦
# Sentiment: negative, Text: legendary. #i_am #posit #affirm
# Sentiment: negative, Text: unit state america, from rest world: think you'v proven don't have right firearms.
# Sentiment: negative, Text: hold open door woman becaus she' woman becaus it' nice thing that' don't even deni
# Sentiment: negative, Text: when your have good weekend show #thank #bless #jeffreycwilliam ðâ¦
# Sentiment: negative, Text: when have good help everyon alway seem get #buttru
# Sentiment: negative, Text: happiest babi ever knownð #cute #smile #babygirl #beauti #niec #bless
# Sentiment: negative, Text: readi #t.b.c #oneteamlincoln are... ð
# Sentiment: negative, Text: can't wait carowinds! readi time #rockthepark #timetogetmyjesuson
# Sentiment: positive, Text: alreadi bought find dori ticket
# Sentiment: negative, Text: everi minut lose sixti second #happi should same ðª
# Sentiment: negative, Text: #sanjapan #animeconvent guy september!
# Sentiment: negative, Text: question day: excit motoâsâ¦ #tech #announc #moto_ #question
# Sentiment: positive, Text: make today count! #mondaymotiv #livelifetothefullest #healthi #everydaycount
# Sentiment: positive, Text: happi morn 8degre with anna #classmat #friend 92â¦
# Sentiment: negative, Text: would abl suppo event #brentwood #homesta they lost fund have close
# Sentiment: negative, Text: happi littl peopl ð happyhappi peopl #kitten #cat #blackkittenâ¦
# Sentiment: negative, Text: thank veri much thi oppoun will cherish forev ð¿ð¦ð» ððªð»ðð¼
# Sentiment: negative, Text: ð· themeowood: puppi
# Sentiment: negative, Text: more day till ð
# Sentiment: negative, Text: "happy" pharrel william #pharrellwilliam lyric
# Sentiment: negative, Text: happi w.ork conference: right mindset lead culture-of-develop organ #workâ¦
# Sentiment: negative, Text: lost anoth member famili yesterday:-( #gut #rosi
# Sentiment: negative, Text: yayyy.... trailer 2morrow #fever super
# Sentiment: negative, Text: watch fanci tails' vine "mad #mad #teeth #bite #piss #dog #bite #dogbit #dogtreat
# Sentiment: negative, Text: #dreamcatch bull will domin your bull will direct whatev want when
# Sentiment: positive, Text: readi tomorrow ðððððð#englishteach #teacher #ecuador
# Sentiment: negative, Text: memori wonder dad, alway missed, etern loved. #strong #greatquotesâ¦
# Sentiment: negative, Text: dalla shoot "the video you'r about disturbing, viewer discretion" then they play loop oveâ¦
# Sentiment: negative, Text: #itako#alone#it' fine. little.
# Sentiment: negative, Text: sunshin &amp; sticker kind saturday ð¸ð½ #letthembelittl #childhoodunplug
# Sentiment: negative, Text: wonder today âï¸ #calm #sunni #chubbygirl #glass #finnishgirl #finn
# Sentiment: negative, Text: buka bersama family... #yuhuuuuu #tmaâ¦ risha, meylucky, &amp; other mayfair townhouse) [pic]
# Sentiment: negative, Text: love more than know.ðð #nationalbestfriendsday #true
# Sentiment: negative, Text: thi governor state with biggest african-american popul #â¦
# Sentiment: negative, Text: #stereotyp #prejudic offer #hope solut creat same repetit #hate #conflictâ¦
# Sentiment: negative, Text: pussi quicker these day ð
# Sentiment: negative, Text: i'll probabl time come back home #ugh
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: anyon play voez? kinda love with thi game ððð #game #game #girlgam #voez
# Sentiment: negative, Text: many#pol pass mani time said nothing? #bluelivesmatt #draintheswamp #ferguson
# Sentiment: negative, Text: sequoia about #weekend!
# Sentiment: negative, Text: some bitch care more about their eyebrow then much they makin week
# Sentiment: negative, Text: bham pride paradeready#beyou# #ofbham
# Sentiment: negative, Text: #fathersday guy play there #love ð
# Sentiment: negative, Text: #æ´å®å0616çæ¥å¿«ä¹ bihday bogummy!!!lov forever!hop happi everyday!good night!ð
# Sentiment: negative, Text: wish client babi goat cuddle!
# Sentiment: negative, Text: #positivevib #fresh love guys. some!!! concord mill mall
# Sentiment: negative, Text: #conjuring2 readi scared! tonight it' #readyornot #truestori
# Sentiment: negative, Text: âtoday make change. elimin neg choos live posit lifestyl instead.â
# Sentiment: negative, Text: aaahh! nabilah look ð arigat jkt48! have veri happi daaay âºï¸ #iwearbanana
# Sentiment: negative, Text: last work tomorrow self employ from monday #scare #redditchbizhour
# Sentiment: negative, Text: half half man.... dumb too?? ð¢ð
# Sentiment: negative, Text: happi littl boy! #smile #corbinrayp
# Sentiment: negative, Text: never been more appropriate: have zero idea what feel right #scare #missyou #whatwasthat
# Sentiment: negative, Text: have magnific monday! #mondaymorn #mondaymotiv #monday #indraloka
# Sentiment: negative, Text: just dont understand these design print anim fabric, just bought muzlin #sanasafinaz #noexchangepolici
# Sentiment: negative, Text: mayb happi hour #ending" ó¾®ó¾µó¾­»
# Sentiment: positive, Text: #littlebear friend #joy #toddlerfriend #puresweet #latergram #toddlerfun
# Sentiment: negative, Text: have never lost love senseless violenc don't fuck opinion amend
# Sentiment: negative, Text: where world heading? could lose your life just leav your home. #orlando
# Sentiment: negative, Text: heard that, tri lock shooter kept other patron from get out!
# Sentiment: negative, Text: good mood flight with munich interviews! #pharrel
# Sentiment: negative, Text: first present netherland
# Sentiment: negative, Text: made proud been read word &amp; assur will assoment petit emot wish best.
# Sentiment: negative, Text: happi joy. happi temporari leav last forev never leaves. #real #tru
# Sentiment: negative, Text: twinklatinboy #slut #snapshot #hot #nasti #naughti #sexi #horni #shi #porn #nude #kinki #xxx #y...
# Sentiment: negative, Text: peopl thankful. thank peopl happy. #thankfulthursday
# Sentiment: positive, Text: creative. #i_am #posit #affirm
# Sentiment: negative, Text: have held back tears. have cri happi tear &amp; final leav week tomorrow!!! #canadianrav
# Sentiment: negative, Text: bihday pressi from mummi granni #michaelkor #luckygirl #bihday #liverpool
# Sentiment: negative, Text: stuck athen instead santorini becaus said windi land! shock servic everi level since!â¦
# Sentiment: negative, Text: these happi folk veri first #freakshak launch. #freak #yum #dalston
# Sentiment: negative, Text: what "huge" crowd trump.
# Sentiment: negative, Text: thank saturdays. #thank #posit
# Sentiment: negative, Text: good god, why?! ð³
# Sentiment: negative, Text: enjoy these delici melons! #vegan #organ #fresh #fruit #organ #healthi #healthyliv #life
# Sentiment: negative, Text: first months, then weeks, it' onli day till begin both #sad same time.ðð¢
# Sentiment: negative, Text: it' firework!! weeheeeee~ ððððð»ðð»ðð»ððð
# Sentiment: negative, Text: #blackpool attack bull game realli think that head empti around city. each side
# Sentiment: negative, Text: #fathersday amaz father there today.
# Sentiment: positive, Text: just want that much for? ð
# Sentiment: negative, Text: readi waiting! #newblood16
# Sentiment: positive, Text: sad. aunt pass away. #funer
# Sentiment: negative, Text: horribl from #2016 that made cring
# Sentiment: negative, Text: wouldn't mind robson-kanu decent player. avail free transfer
# Sentiment: negative, Text: come ...you better than this. pleas yourself shoes. unnecessari stress hâ¦
# Sentiment: negative, Text: stalk watch just peon. poor. disabled. kill me.thi #usa use proud &amp; univers doesn't care.
# Sentiment: negative, Text: #stephcurry' outburst beg question: christian #nbafin
# Sentiment: negative, Text: #grate that #affirm
# Sentiment: negative, Text: more week then antonio bound cant wait littl brother! #missyou #mybrotherskeep
# Sentiment: negative, Text: listen &gt;&gt;&gt;&gt;&gt;&gt;&gt;
# Sentiment: negative, Text: "the die light" villag green/townâ² #antisemit #hocoschool #columbiamd #hocomd
# Sentiment: negative, Text: hahaha.. thi last #friday &amp; #weird
# Sentiment: negative, Text: hey, notic that train lover, check free app, it' known training" appl
# Sentiment: negative, Text: sexi fuck #direction #niall #nialhoranfact #niallerwin #hot #justindrewbieb #justindb #believetou...
# Sentiment: negative, Text: #father'sday! love you" your right now! #sanya #whererefreshingbegin
# Sentiment: negative, Text: guess back, back again! #lifeaftersurgeri ðð¼#dog #dogslif #labrador #labradorretriev #lifeofsam
# Sentiment: negative, Text: superspoilt, want check latest updat #glastofest ð¥_
# Sentiment: negative, Text: bihday sid... bless you.. success career
# Sentiment: negative, Text: final ambival love steph thompson, kyri stink green class doosh, lebron won't talk guillermo
# Sentiment: negative, Text: check product team' web-seri episod that edit your truly. #mep #webseri
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: never answer about your statement #nazi' over #hatred, &amp; #bigotri be found wâ¦
# Sentiment: negative, Text: #juneteenth #independenceday #food4thought #rich #ancestr #heritag independ hall
# Sentiment: negative, Text: #river gorilla simulator: need adapt environment. need tear city. materi
# Sentiment: negative, Text: watch leadership embrac &amp; kiss donald' #pathet &amp; thi pay. racism &amp; hate. #ripgop
# Sentiment: negative, Text: love matur ageð ð¤ð
# Sentiment: negative, Text: yeah it' good bing bong bing bong
# Sentiment: negative, Text: it' such good feel when thi happens. #smile #instalik #instamood #instap
# Sentiment: negative, Text: check #graffiti #dublin #ireland #music #vimeo #movi #video #europ #peopl #flow #fun #rafalwojcicki
# Sentiment: negative, Text: #oitnbseason4 days!!! aaahhhhh
# Sentiment: negative, Text: it' #iamposs today! #extraordinaryladyspeak #staraward htâ¦
# Sentiment: negative, Text: out! happi thursday! âï¸ð»âï¸ð»âï¸ #breakfast #sun #day #sunnyday #sun #blueâ¦
# Sentiment: negative, Text: pack sneak-peek! work with #yellowjacket #neshl 2016! #bhl #hockey
# Sentiment: negative, Text: toni sunday! #tonyaward
# Sentiment: negative, Text: happi father' 2016 dad' there!! #fathers#day #2016
# Sentiment: negative, Text: theverdict idiot #countri #rock #bluegrass #beatl #love #pop #romanc
# Sentiment: negative, Text: #project week, june 2016 #blog #silver #gold #forex
# Sentiment: negative, Text: #300dayshappi #dayseventyseven #day77 #happi #love#lifequot #lifeâ¦
# Sentiment: negative, Text: littl brother higher toler alcohol than
# Sentiment: negative, Text: wish thi #bihday blaze say spit imag aâ¦
# Sentiment: negative, Text: thank hike trails. #thank #posit
# Sentiment: negative, Text: meet tackl movi which uncov problem don't want world know.
# Sentiment: negative, Text: chill relax piano music keep your #quiet dure #july4th #firework
# Sentiment: negative, Text: might libtard if... #libtard #sjw #liber #polit
# Sentiment: negative, Text: noth say 'merica, like that tweet.
# Sentiment: negative, Text: alway #paratyphoid
# Sentiment: negative, Text: "today lost #thevoic sister senselessli sing love death people." #stoptheh #ripchristina
# Sentiment: negative, Text: some guy concern about their twitter "brand" honest with their followers.
# Sentiment: negative, Text: hate like family.... realli born into toxic bomb! mother fucker don't give fuck about money
# Sentiment: negative, Text: #enjoy #music #today #free #app #free #music
# Sentiment: negative, Text: best #lawofattract #resourc #healing! #altwaystoh #healthi #idwp
# Sentiment: negative, Text: trump co-chair make racist remark about michel obama #p21 #fyi #tcot
# Sentiment: negative, Text: fan? thi should make
# Sentiment: negative, Text: #music #therapi tool #healing! #altwaystoh #healthi
# Sentiment: negative, Text: food make famili fight
# Sentiment: negative, Text: delici sangria#salud#ch #smile pembrok
# Sentiment: negative, Text: have fabul weekend beauti soul #nofilt ð
# Sentiment: negative, Text: when feel #overwhelm look down million reason #happi again. love craig!!
# Sentiment: negative, Text: back shane lowry!
# Sentiment: negative, Text: hour right now! 2-4-1 bottl &amp; drink from 4-7pm chippewa #buffalo
# Sentiment: negative, Text: ana nimra farishta mawia khushal 3334 number mark obtain damn high
# Sentiment: negative, Text: monday empti without bachelorett ð©ð¹ð· #thebachelorett #empti #nowin
# Sentiment: negative, Text: suppo family, god, chivalry, tradition, pride one' heritag controversial.
# Sentiment: negative, Text: say otherwis young girl confin that kitchen. void meaning, beyond cheap public #topoli
# Sentiment: negative, Text: #good night! #faith ever #vaitacacommafiasdv
# Sentiment: negative, Text: what love simpli love #love #success #work #businessâ¦
# Sentiment: negative, Text: lunchtim with mom. #torrington #lunch #afterschool #instadaili #yummi #withmom
# Sentiment: negative, Text: sister ain't even know watch argu with nigga ððð wait wrong shit
# Sentiment: negative, Text: ride out, ride back ...done! #cycl #sunset #ride #bike #fit #cardio #deseâ¦
# Sentiment: negative, Text: well gonna adtr with bae...
# Sentiment: negative, Text: #tagsforlik #food#friends#summer#swag#quot #love#god#girl #weekend #polaroid #followm #teen #win#job
# Sentiment: negative, Text: #payintheusa polar bear climb racing: angri polar bear climb racing, polar bear live cold place
# Sentiment: negative, Text: 11:11 healthi
# Sentiment: negative, Text: dream palace, move already? #stellar #girl #dreami #goodmorn daysâ¦
# Sentiment: negative, Text: wait follow sinc factor
# Sentiment: negative, Text: it' your fault have pointscore.
# Sentiment: negative, Text: thi week sta kinda lame it' get better! #yay #wednesdaywisdom
# Sentiment: negative, Text: #forev young luk temper i'll alwi till breathâº hâ¦
# Sentiment: negative, Text: don't worri #bee
# Sentiment: negative, Text: doubl follow #beauti #smooth #lifestyl #skin #instas #f4f #fashion
# Sentiment: negative, Text: #lawofattract #heal #loa #healthi #well #idwp
# Sentiment: negative, Text: #oil turn flat $50.40, eye inventori data fuher direct #blog #silver #gold #forex
# Sentiment: negative, Text: train employee' fun. #newblood
# Sentiment: negative, Text: #first #bihday #puppi #elois #sweetbabin #dog #growingup #cute #bihdaygirl
# Sentiment: negative, Text: 5,000 pig burn aliv saskatchewan barn fire (video)
# Sentiment: negative, Text: you'll never convinc that american have right bear these. #prayfororlando #guncontrol
# Sentiment: negative, Text: with beauti ladies!!! bless know them !!ó¾¬ó¾¬. #smile #lovethemâ¦
# Sentiment: positive, Text: today baba siddiqu ifftar mumbai. &amp; dono ayenge. both again
# Sentiment: negative, Text: hand #ombr #blue
# Sentiment: negative, Text: can't wait warcraft, ð­ð­ð­ #warcraft
# Sentiment: negative, Text: cousin reunited... #family#fun well
# Sentiment: negative, Text: audienc with duan henri ....should veri insight
# Sentiment: negative, Text: train hasn't move bing tweet
# Sentiment: negative, Text: have lover stop be angri visit us..&gt;&gt;&gt; #lover #friend #astrolog #love
# Sentiment: negative, Text: when you'r block troll becaus promis #blacklivesmatt &amp; nonsens rant boosâ¦
# Sentiment: negative, Text: father' dad here one' that heaven
# Sentiment: negative, Text: #sdl326am june
# Sentiment: negative, Text: creepi awesom these baboon climb fire escap like human #summev #zoo
# Sentiment: negative, Text: power your mind #heal your body! #altwaystoh #healthi
# Sentiment: negative, Text: dude tiger! #roar #tiger #annaswelshzoo #bihdaycelebr
# Sentiment: negative, Text: don't #laugh becaus we'r happy... we'r becaus laugh. william james. #xtra
# Sentiment: negative, Text: have happi sunday everyone! think today go good #positivevib #sunshin #sunday
# Sentiment: negative, Text: talk about way which organ dehuman they'r never held accountable?
# Sentiment: negative, Text: stuck race? find your freedom. #masterkeyexperi
# Sentiment: negative, Text: have study... #face #pizza stole roommate' idea take thi pic)
# Sentiment: negative, Text: dinner with sister!! ðâ¤ï¸ð¯ð #sisteradventur #sister #ilovemysisterâ¦
# Sentiment: negative, Text: els plan watch tomorrow? ð ð
# Sentiment: negative, Text: #usn rifl 'snow out', ar-15 closest m-16 ever got. #navi
# Sentiment: negative, Text: euro 2016: pundit make their predict franc #euro today
# Sentiment: negative, Text: becaus happy! ðð #happi #minion
# Sentiment: negative, Text: elder scroll mani years?!! #bethesda #e32016
# Sentiment: negative, Text: poor #tiggi ð¢ littl cheeki #jax &amp; ð #soa #throwbackthursday
# Sentiment: negative, Text: cannot wait #eurogam thi year! #pump #eurogamer2016
# Sentiment: negative, Text: veri work with russell.beckwith soon #staytun ð¸: friend lyle!! #tapfoag ..â¦
# Sentiment: negative, Text: nazi studi american race law inspir #ushistori #eugen
# Sentiment: negative, Text: share cream #sun #love #outdoor #picnic #summer #famili #daughter #father #dess #icecream
# Sentiment: negative, Text: noth like river island sale shop spree cheer #retailtherapi #riverisland #shoppingqueen #alwayscheersyouup ð¸ð¼
# Sentiment: negative, Text: clean hous zo laundry. final free from fever colds. â©__â©i'm happy! #clean #laundryday
# Sentiment: negative, Text: list #ebay #woohoo #sell #sell #buy #shop #shop
# Sentiment: negative, Text: thank challenges. #thank #posit
# Sentiment: negative, Text: chill night with cream&amp; grown up2! #chill
# Sentiment: negative, Text: #biher absolut origin hate #bigotri #altright hatr african american #potu #theresist
# Sentiment: negative, Text: sweet ð°ð©ð¬ð­ð«â¨!!!!!! #instagood #ìì´ë #å¶å #idola #idol #à¹à¸­à¸à¸­à¸¥ #followm #selfi #ã©ãããâ¦
# Sentiment: positive, Text: these tragedi america first with kill #christinagrimmi #orlando #america safe place today!
# Sentiment: negative, Text: #brexit angst factor help drive down interest rate germani japan #blog #silver #gold #â¦
# Sentiment: negative, Text: &amp; interest #eacbpm. dash quiet place dial into iiba emea region meet #busi
# Sentiment: negative, Text: kayak, sup, snorkel, swim...whatev your pleasure, we'll together! #alohabeachbu #hawaii #explor
# Sentiment: negative, Text: hold down year ...and watch chang over some hear say.. loyalty.. no...
# Sentiment: negative, Text: we'll back go tacloban now! later!ó¾µâ¤ #great travel tacloban citi from catbalogan
# Sentiment: negative, Text: feel about that? haven't olymp medal
# Sentiment: negative, Text: angri bird film download 720p hdtc (2016) #bird #download #film #ita
# Sentiment: negative, Text: #sunday ð #photo #model #urbex #topless #tit #mono #retweet #sexi #heel #ace
# Sentiment: negative, Text: offic viral arrest video ârude racistâ: chief #crime #officerâ¦
# Sentiment: negative, Text: saturday friend
# Sentiment: negative, Text: yayyyi friend marri today ð°ð°ð°ð«ð« congratul guys. â¤ï¸â¤ï¸ #shegotmarri
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: lewi remain perfect, ranger announc gonna stroke out.
# Sentiment: positive, Text: chri back #soccer after miss most #spring #season with brokenâ¦
# Sentiment: negative, Text: train ticket book opera week wale
# Sentiment: negative, Text: it' beauti day..... #sun #fun #beachpark beach park
# Sentiment: negative, Text: screen be fit right #euros2016
# Sentiment: negative, Text: love stori happi ending. #anim #love #stori #not #end #like4likeâ¦
# Sentiment: negative, Text: #poet bull will domin your bull will direct whatev want when
# Sentiment: negative, Text: tranquil. #i_am #posit #affirm
# Sentiment: negative, Text: that name upcom track? ðð #2pm #kpop
# Sentiment: negative, Text: best #essentialoil #anxieti #healthi #peac #altwaystoh
# Sentiment: negative, Text: some people' children have noth better then insult peopl twitter
# Sentiment: negative, Text: think mayb should have bought instead #gettingold #becomingbor #notborderland #goblizzard
# Sentiment: negative, Text: fact that album hour away from drip lose mind.. #fatkidinacandystor
# Sentiment: negative, Text: ryderrideu together: #snapshot #young #shi #kinki #wet #porn #hot #xxx #horni #s...
# Sentiment: negative, Text: ð¸ð»ð¼ððº snapchat: gaby_china20 #love #girl #snapchat #flower #instasmil #instaloveâ¦
# Sentiment: negative, Text: brilliant. #i_am #posit #affirm
# Sentiment: positive, Text: true nigga dont look apament they look shoe jewelri
# Sentiment: negative, Text: safe way heal your #acne!! #altwaystoh #healthi #healing!!
# Sentiment: negative, Text: #msgapparelstoday special father
# Sentiment: negative, Text: camp next weekend. #lovecamp #brownwood
# Sentiment: negative, Text: #grate that #affirm
# Sentiment: negative, Text: #forev besti ð #karaok #friend #friendship #love #nofilt #instacool #instagood
# Sentiment: negative, Text: absolut love thi place. fantast welcom from carlos, receptionist. time here. room request grant usual. #318
# Sentiment: negative, Text: head #thealter with peculiar family!
# Sentiment: negative, Text: retail sale control group like rose 0.2% dansk bank #blog #silver #gold #forex
# Sentiment: negative, Text: happi father day. love life &amp;th best father world. â¤ï¸ð #fathersday #love
# Sentiment: negative, Text: coolestlifehack: world smallest snake #motiv
# Sentiment: negative, Text: thi shockingli increasingli #violent #world live control laws. feel mp' famili &amp; friend
# Sentiment: negative, Text: #funni simpli #truestori
# Sentiment: negative, Text: happi bihday me!... brithday holiday #monday #menmodelsâ¦
# Sentiment: negative, Text: sadden that no-on thought groom posit befor ask opinion such issue.
# Sentiment: negative, Text: ukrainian athlet grosseto watch livestream without see them it' same...
# Sentiment: negative, Text: season oitnb sta tonight ðð¼ #oitnbseason4 ð¬ð¬
# Sentiment: negative, Text: excit other side cuain onc tonight. look forward see broadwayâ¦
# Sentiment: negative, Text: when quay collab with say sold out!!!ð©ð«ð©ð«ð©ð«ð©ð«ð©ð«ð©ð«ð© #noooo #whyyyy #loveyoudesi
# Sentiment: negative, Text: final #jordan #paid #wear them too! #lowtopsâ¦
# Sentiment: negative, Text: impressive. #i_am #posit #affirm
# Sentiment: negative, Text: father' father there there make happen ...... #salut y'all
# Sentiment: negative, Text: view from 27th floor! #nyc #newyorkc #myview girl #wine #fridaynightâ¦
# Sentiment: negative, Text: discuss republican same thing critiqu can't ignor consequences.
# Sentiment: negative, Text: school tomorrow last integr
# Sentiment: negative, Text: amen!! truth. always. &lt;3 &lt;3 #love #bless
# Sentiment: negative, Text: stamford month rape.but that wasn't boredom...it minut action.
# Sentiment: negative, Text: let color your life rainbow #danian #love #colour #rainbow depok
# Sentiment: negative, Text: #aiel #aielmaharashtra rude custom care execut make want switch loyalti anoth provider. #irrit
# Sentiment: negative, Text: teddi corpuz... #rocksteddi #band #enjoy #idol #omg ððððððð
# Sentiment: negative, Text: wow, what great daughter are! send that your father right befor father' day. #cheapshot #lowblow #shame
# Sentiment: negative, Text: reason happyâ¦when your mid-tantrum #parent #tantrum #toddler #calm #mind #strong
# Sentiment: negative, Text: truthful. #i_am #posit #affirm
# Sentiment: negative, Text: #siri #maco #wwdc2016 woot! next they work listen skills?
# Sentiment: negative, Text: #diy done! #dresser #nicknack #newelectricscrewdriv brock london
# Sentiment: negative, Text: #black &amp; feel like stomp you? #retweet #tampa #miamiâ¦
# Sentiment: negative, Text: that problem, onli polic officer. need more, with bigger gun perhap tank with soldiersâ¦
# Sentiment: negative, Text: father' friends#
# Sentiment: negative, Text: you'r with your #choic thi fall, #alway write candid in..
# Sentiment: negative, Text: #ë¤ì´ì_ê·¸ê¸¸ìì_ì¤í¸ë¦¬ë° #ê·¸ê¸¸ìì #ì°ìµì end
# Sentiment: negative, Text: know team behind #app that' keep tummi #june #issu #bazaarmagâ¦
# Sentiment: negative, Text: actual go fish today somewher nice âºï¸ð.
# Sentiment: negative, Text: cute, they both look like dolls.
# Sentiment: negative, Text:
# Sentiment: negative, Text: love thi vacat ð #enjoy #greec #crete #sabinedrift #chillinn #blondegirl #bluedressâ¦
# Sentiment: negative, Text: unreal advisor refus take payment!?? wait thi custom servic when site wasnt working??
# Sentiment: negative, Text: #gamereadi forza horizon what time live in...
# Sentiment: negative, Text: life better tahiti #summer #life #no_school #tahiti #like
# Sentiment: negative, Text: know their male thought they vagina like video game #stupidthought #quot #lmao
# Sentiment: negative, Text: pack taken brainwash cheetah #downasquadmemb #treeout
# Sentiment: negative, Text: #japan domest corpor good price index (yoy) line with expect (-4.2%) #blog #silver
# Sentiment: negative, Text: rememb when peopl #bbuk went becom realiti stars, seem realiti star becom brother contestants.
# Sentiment: positive, Text: #allahsoil more familiar becom more difficult stereotype. â¦â¦
# Sentiment: negative, Text: #good #morn want live life, goal, peopl things.
# Sentiment: negative, Text: friday &lt;3 #fridayfeel #relax #bristol
# Sentiment: negative, Text: day porn movi pussi pic
# Sentiment: negative, Text: look easi till turn #rap #hiphop #rock #funni #comedi #pop #kanyewest
# Sentiment: negative, Text: banner #merri #christma #new #year #freepik #decor newyear
# Sentiment: negative, Text: yay! thank let know. will veri happi man!
# Sentiment: negative, Text: exam room ð­ð­ð­ #test #tire #annoy #whi
# Sentiment: negative, Text: best homeopath remedi #anxieti #altwaystoh #heal #peac
# Sentiment: negative, Text: rest peac christina.
# Sentiment: negative, Text: those bama fool around with might rais your child. dont think that advance. they just "fun" whatev
# Sentiment: negative, Text: anti racist codeword antiwhit asia asian africa african white countri everyonâ¦
# Sentiment: negative, Text: #periscope: first babi graduat from high school!!! #collegebound
# Sentiment: positive, Text: nearli there folk #nervou #curiou just finalis stuff with pointer from grainn #bringiton
# Sentiment: negative, Text: fellowship. ð #lifegroup
# Sentiment: negative, Text: just caught myself eat chocol slice bread besid realiz still didn't dinner.
# Sentiment: negative, Text: #prais #cleveland polic dure #rnc polic under consent decree! #white #tamirric #rip
# Sentiment: negative, Text: best #lawofattract #resourc #healing! #altwaystoh #healthi #idwp
# Sentiment: negative, Text: everyth need #surfday. #fathersday #dad there from #novyspos.#novytowel#surfgear
# Sentiment: negative, Text: 100% agre
# Sentiment: negative, Text: next show monday fiddler' elbow camden. it' look like it' go huge night! htâ¦
# Sentiment: negative, Text: swim sign everywhere. parent' weren't watch year old.
# Sentiment: negative, Text: mitchellrattl mitchel goodson
# Sentiment: negative, Text: get readi saturday' jeep with nbjc! day until #showyourjeepday #jeepmafia #jeeplif #jeep httâ¦
# Sentiment: negative, Text: attempt czech fury, onli croatia score their second.
# Sentiment: negative, Text: latest dairi k.s! thank #ä½éå æ¥
# Sentiment: negative, Text: grate everyday :)))) #gratitud #laurasworld
# Sentiment: negative, Text: i'v ebook awhil it' nice have hard copy!!!
# Sentiment: negative, Text: finals. game what more could basketbal for?! #nbafin
# Sentiment: negative, Text: that doesn't prevent from be #bigot
# Sentiment: negative, Text: dear #uot, despit attempt #savecharity, regret announc that we'v lost her! #tragic #rip angel friend. will miss
# ...
# Sentiment: negative, Text: problem with troll it' alway same same old. they'r never origin witty. there' spark there. joie vivre.
# Sentiment: negative, Text: #hapoyfathersday #kimkardashian wish #kanyewest father ðððððððð cheekâ¦
# Sentiment: positive, Text: #soalegends!;) #tig &amp; caus #kozig! lol! &amp; htâ¦
# Sentiment: negative, Text: test day! shoot thursday! #360 #360video #music #videoclip
# Sentiment: negative, Text: came sideway you'r do much &amp; your spot ð
# Sentiment: negative, Text: boston ð
# Sentiment: negative, Text: come =fraud &amp; document #liar lost base after call them #nazi #brownshi he' pivoâ¦
# Sentiment: positive, Text: current watch #eve miss thi show much pure dope yeeeeeessss
# Sentiment: negative, Text: instead usual #ripdad fathersday here' someth chang &amp; #itsaboy
# Sentiment: negative, Text: guy thi demi lovato alway number everywher #coolfohesummervma #confid
# Sentiment: negative, Text: smiling, cheering, cri #americanninjawarrior
# Sentiment: negative, Text: flower father' dayð¤ #father #day #daddi
# Sentiment: negative, Text: alway ð½ð¢ð®ð¢ð¢ð§
# Sentiment: negative, Text: #insectstalk attack bull game realli think that head empti around city. each
# Sentiment: negative, Text: senat warren best qualifi peopl year senator. when republican nomine call goofi pocahonta
# Sentiment: negative, Text: #cute blond tenni girl #carolinewozniacki #sunshin #day #smile
# Sentiment: negative, Text: natural. #i_am #posit #affirm
# Sentiment: negative, Text: might libtard if... #libtard #sjw #liber #polit
# Sentiment: negative, Text: thi happy! #vegan #fresh #healthi
# Sentiment: negative, Text: happi #lgbtfamily,but what don't incess thin veil against other minorities?
# Sentiment: negative, Text: graduat from #usa &amp; friend want forget rector against #islam
# Sentiment: negative, Text: there' much mayhem go with shoot bombing, bare keep with all.
# Sentiment: negative, Text: french feet water tonite? #soccer with #scotland #france! haa!:) fair play!
# Sentiment: negative, Text: #pray jehovah chereb' #will #done #thruout grove #andrew #jamaica ijn|remov #stalker &amp; #organizedcrim thug #jesu
# Sentiment: negative, Text: 10pm tonight #comedynightsl #superfun #mad #rockstar
# Sentiment: negative, Text: thi song f*cking awesome, thrill album! #cantwait #palyhappi
# Sentiment: negative, Text: just isn't same without cover togeth #g4waslif #missyouguy
# Sentiment: negative, Text: know scary, isn't
# Sentiment: negative, Text: teach ó¾µó¾® photographi #ramodmalaka #coolstep #danc #danceworkshop #matara #smile...
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: sunni sunday ðððð #maraton #runner #run #travel #zipaquira #bogotadc #colombiaâ¦
# Sentiment: negative, Text: norway kill more whale #whale #norway #killingwhal #cruel #scandinavia
# Sentiment: negative, Text: thi what #ladi like... this? thi white house. you'r shame.
# Sentiment: negative, Text: absolut wick #brockwellpark #housem #summer #london #love #dreamteam #hairbraid
# Sentiment: negative, Text: suspect peopl
# Sentiment: negative, Text: poor kevin love went high-fiv from lebron jame instead yell #nba #bro #fail #epicfail
# Sentiment: negative, Text: senseless death...no shld ever have thi way.
# Sentiment: negative, Text: tell he' mole
# Sentiment: negative, Text: #westvillag #wine #aria aria west villag
# Sentiment: negative, Text: aptli named... have whitesboro with kill town seal, whiteland with mascot
# Sentiment: negative, Text: hardcor set teen bikini
# Sentiment: negative, Text: that present âcurv with confidenceâ #clothesshow 2016. your tickets!!
# Sentiment: negative, Text: work with develop your greencommun thi summer #fun #sustainableliv
# Sentiment: positive, Text: check book elli past p.m. when librari open until p.m.? #justwannacheckoutbook #nerd
# Sentiment: negative, Text: just move &amp; kid realli hous myself already..
# Sentiment: negative, Text: #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# Sentiment: negative, Text: thi #toilla #final #eaten
# Sentiment: negative, Text: free porn hardcor
# Sentiment: negative, Text: found favorit song #showemwhatyouremadeof #backstreetboy #perfectharmoni
# Sentiment: negative, Text: here!! #new #product #brochur #foreverliv #2016 #loveyourbodi #treatyourselfâ¦
# Sentiment: negative, Text: dj_ham-new_style__your_love-(ng018)-web-1998-ukhx_int #next gener #web hardcor #1gabba
# Sentiment: negative, Text: tiiiiim #emmalouandtheagenda #gig #music
# Sentiment: negative, Text: silence. ð¶ #silenc #alon #captur #ey #brow #girlgrung #girl #like4likeback #lookâ¦
# Sentiment: negative, Text: news that year drag into water #disney reso what expect read today. #muchlov #natur
# Sentiment: negative, Text: #mcmð thay great day! #inshot #girl #cute #summer #blur #sun #fun #dog #hairâ¦
# Sentiment: negative, Text: #break #tenderfootfir burn acr near #yarnell. live coverag #gmaz #heabreak #azfamili
# Sentiment: negative, Text: beauti feel when made surpris visit #icu nurses, priceless! after brain surgery. best #btsm
# Sentiment: negative, Text: -&gt; -&gt; sirf ashiq follow karen #iqbal #galib #wasi #faraz #sagar #mohsin full poetry, #shairi follow send 4o4o4
# Sentiment: negative, Text: wait flight ð#airpo #manchest #spainðªð¸ #flightâ¦
# Sentiment: negative, Text: unfounately, we'r friend more...
# Sentiment: negative, Text: root beer stormðð #rootbeer #storm #rain #ð #thunder #lightn #car #caffin #fordâ¦
# Sentiment: negative, Text: more news, mother past away. alon isol mayb time marry. #death #alon #isol
# Sentiment: negative, Text: week thi picture. week monday. long #babygirl #bumpi
# Sentiment: negative, Text: ,#canufeelit ð #rickastley50 best age
# Sentiment: negative, Text: soon... doctor tribute... #alldoctor 1963-2015
# Sentiment: negative, Text: newli furbish rooms... #summer #open #placetob
# Sentiment: negative, Text: lonely? #friday#weekend#shooging#photo#monochrome#healthy#camera#japan#girl#model#love#lâ¦
# Sentiment: negative, Text: what funni that most world think gay happi group look equality. much fight behind scene smdh.
# Sentiment: negative, Text: #bravewarrior #disappoint stil fan!
# Sentiment: negative, Text: #music #therapi tool #healing! #altwaystoh #healthi
# Sentiment: negative, Text: when naã¯v girl here been feel them bcuz y'all realli look thi shit valid accept
# Sentiment: negative, Text: bihday
# Sentiment: negative, Text: chase your ð then it' #magic ð«
# Sentiment: negative, Text: #fathersday #number1 #man #life ð
# Sentiment: negative, Text: them #lambridg #famili #kid #fathersday
# Sentiment: negative, Text: health life ðð»ðð #fruit #health #life #love #miam #dragonfruit #black #yellow #strangeâ¦
# Sentiment: negative, Text: mayb you'll understand till then you'r go life &amp; make miser don't nâ¦
# Sentiment: negative, Text: black peopl will diss #presidentobama then talk about great #hillari black community.
# Sentiment: negative, Text: dream handshake. good smell like rosesâ¦ #xjapan #dream (ïï-).oâ¥
# Sentiment: negative, Text: #blowoutsbringhappi anoth client! have book your appoint nohpark yet?!...
# Sentiment: negative, Text: rox hogay bodi invit iftar #buhatnainsafi
# Sentiment: negative, Text: cannot open play fire use spo go!!!! #upset
# Sentiment: negative, Text: ðððð bansod here girl onli #sultantrailerfastest20mview
# Sentiment: negative, Text: wouldn't want #wed #venu like this? #destinationwed #love #beauti #palac
# Sentiment: negative, Text: #datenight with heabeatsâ£ #selï¬ #smile #miaminight #amctheat #aventuraâ¦
# Sentiment: negative, Text: when excit about summer then rememb your take geometri collegeðð­
# Sentiment: negative, Text: happi day long &amp; wild
# Sentiment: positive, Text: open "my" #rollerblad season, today! #summer #rollerblad #belgrad #adaciganlija
# Sentiment: negative, Text: #littl owls!
# Sentiment: negative, Text: #stephcurry' outburst beg question: christian #nbafin
# Sentiment: negative, Text: have #idealpan doesn't mean you'll what' there? (via
# Sentiment: negative, Text: doe anyon know what plan thi race anymore? #runner #tiffani
# Sentiment: positive, Text: tomorrow will tackl move from laptop macbook #deliveri #technolog #appl #sync wish luck!
# Sentiment: positive, Text: #awesom hardwork dad celebr #fathersday today "they work giant metal man'
# Sentiment: negative, Text: wish stop hide it' hard peopl know. it' hard show them that matter what, still
# Sentiment: negative, Text: sorri pain anguish thi brought your area #orlandostrong #orlando
# Sentiment: negative, Text: go cinema tonight with (who prob just know about magicians) #nowyouseeme2 movie!
# Sentiment: negative, Text: bright side thoughh..... wed dress appt saturday!!! ððð°ð½
# Sentiment: negative, Text: #tattoosleev gorilla simulator: need adapt environment. need tear city.
# Sentiment: negative, Text: ranveer' parent delhi #indianoftheyear ceremony.
# Sentiment: negative, Text: today beauti day! #dragon#boat#festiv
# Sentiment: negative, Text: hope it' plenti pictur becaus can't understand word cycl #higang
# Sentiment: negative, Text: lovely.#i_am #posit #affirm
# Sentiment: negative, Text: sign today folks, have great #weekend everyone! #wish
# Sentiment: negative, Text: thank have freedom. #thank #posit
# Sentiment: negative, Text: long now!!!! #euro2016 #eng
# Sentiment: negative, Text: don't have words. #orlando
# Sentiment: negative, Text: everi view should look like this. #dese #ocean #cactu #outdoor #life #breath #mountain #air #summer...
# Sentiment: positive, Text: seek probe into #udtapunjab' leak, point finger #amarinder, #aap
# Sentiment: negative, Text: great time summer pay!! #filmbi #aarhu #tan #film
# Sentiment: negative, Text: told visit time close account, fast &amp; have drive hour out! #frustrat
# Sentiment: negative, Text: hate guardia #newark thi reason more than other
# Sentiment: negative, Text: take gun away give peopl guns... honestli doesn't matter becaus peopl gonna still hate what they want
# Sentiment: negative, Text: life' ride #nashvil #well #healthi #travel #adventur
# Sentiment: negative, Text: tysvm! #monday have great week!"
# Sentiment: negative, Text: detroit have stronger claim wings' revenu cours kevyn won't comment.
# Sentiment: negative, Text: hate wake #reason. hate be angri period. #bpd
# Sentiment: negative, Text: pool peopl #sonarnar ð¦ð¦ð¦ #getwet #sonar #barcelona #spain #friend #lover factâ¦
# Sentiment: negative, Text: what happen tribut that glad didn't blink! #cmtaward
# Sentiment: negative, Text: regist #run race 11/09 10miler will final meet ðð»ððð
# Sentiment: negative, Text: grow along with best ârobe brown #wed #love
# Sentiment: negative, Text: can't wait anymor ðð onli left ðð ð well even it' min still ð can't control ð
# Sentiment: negative, Text: go twenti pilot conc juli
# Sentiment: negative, Text: yes! herb alp under full moon.
# Sentiment: negative, Text: thank cats. #thank #posit
# Sentiment: positive, Text: free download stori thing #illustr #zine #freeebook
# Sentiment: negative, Text: onli compani allow peopl critic about themselv truli successful.
# Sentiment: negative, Text: peopl stop be pedant leav sheeran alon
# Sentiment: positive, Text: happi often sneak through door didn't know left open. ððª #ootd #funâ¦
# Sentiment: negative, Text: #healthi ever think about give rememb held long. hayley william
# Sentiment: negative, Text: first time premium drinkâ #english loung #oregon cafe game âºï¸ð
# Sentiment: negative, Text: today' #morn want wear #lenses. bloodi #eyes: want much, xoxo
# Sentiment: negative, Text: ðð
# Sentiment: negative, Text: #nowplay highclouds30 (#hc30) nâ°7 thi week!
# Sentiment: negative, Text: alway happy!!! #life #love
# Sentiment: negative, Text: hair launch soon can't wait show case wigs!!!!
# Sentiment: negative, Text: #thing make #blacksabbath #berlin #theend #metal #ilik brandenburg gate
# Sentiment: negative, Text: first half done real half begins.... #pileupriddim video shoot atlantaâ¦
# Sentiment: negative, Text: stock week sharpli lower anxieti grow ahead brexit vote #blog #silver #gold #forex
# Sentiment: negative, Text: excit have wed featur lancashir bride! exciting! #wed #photograph
# Sentiment: negative, Text: kkinet band goin down..... warner chappelâ¦
# Sentiment: negative, Text: #thankyou 200+ sub #motovlog #cake
# Sentiment: negative, Text: beautiful. #i_am #posit #affirm
# Sentiment: negative, Text: rep chicago year today, kany omari west born atlanta, bihday
# Sentiment: negative, Text: amaz health benefit cucumbers! #healthi #doplants!
# Sentiment: negative, Text: arm #workout #comedi #funni #vine #gay #lgbt #lgbtq
# Sentiment: positive, Text: #virgin employe happi #bosch famili cultur guid hire
# Sentiment: negative, Text: #soul local #florida shop #handmad
# Sentiment: negative, Text: decad later, sick among airmen after hydrogen bomb accid york time #comeonusa
# Sentiment: negative, Text: final arriv programmeðð¬ð§ #celebr (hope gift left stage doorð)
# Sentiment: negative, Text: face hors ride#rid hard
# Sentiment: negative, Text: #ojmadeinamerica just remind biggest fall america histori
# Sentiment: negative, Text: it' #smilepowerday! show your best cheesi grin pearli white #smile #teeth
# Sentiment: negative, Text: thank good news. #thank #posit
# Sentiment: negative, Text: gentl soul rest perfect peac #godsavesusal
# Sentiment: negative, Text: nice trip field #sunni #sun #niceday #warm #blueski #relax
# Sentiment: negative, Text: check 48thweeksari "#jesu said,fath forgiv them,for they dont know what
# Sentiment: negative, Text: enjoy hour everyday draught beer imfl #gotcha #loung #bar #bangalor
# Sentiment: negative, Text: best luck you! ððª
# Sentiment: negative, Text: guess he' gonna persist with thi anti irish vitriol.
# Sentiment: negative, Text: today welcom deleg from &amp; #mdambassador
# Sentiment: negative, Text: don't think find someth that didn't photo shop #fuckyoujam
# Sentiment: negative, Text: yeah it' good bing bong bing bong
# Sentiment: negative, Text: carv #fish #brunett #polishgirl #karakalem #draw #selfi #instalik #instas #instamood #hair #â¦
# Sentiment: negative, Text: love neighbor decor with beauti flowers!
# Sentiment: negative, Text: hate sta wildfir more hate. instead come togeth just hate each other have differ polit views.
# Sentiment: negative, Text: summer intern, andrea dowlen, arriv offic thi morning! work #together.
# Sentiment: negative, Text: woke befor alarm thi morning! #adrenalin #nerv
# Sentiment: negative, Text: good morningððâï¸ðððð» #smile
# Sentiment: negative, Text: #mood ..... hump day. #easyglam #beachvib #summer,summer, summer time...
# Sentiment: negative, Text: #worldoceansday #letswork keep #ocean #clean #dolphin #mermaid #sealif
# Sentiment: negative, Text: watch angri grandpa react gift hous video: #grandpa #hous
# Sentiment: negative, Text: gloriou race. #3athlonlif #gtr100 70.3 staffordshir #sun
# Sentiment: negative, Text: total need 1:01:43hr which best perform sprint #triathlon
# Sentiment: negative, Text: go #lilhom wake today. thi shit just #pleasestoptheviol
# Sentiment: negative, Text: [1465518559.23] updat #social #analyt #success #tbt #maiala #run
# Sentiment: negative, Text: #bridetob #bridesmaid even #groom find #weddingwednesday #yorkshirehour #love
# Sentiment: negative, Text: #samanthabe offer respons #orlando shooting, lack action #gun law
# Sentiment: negative, Text: morn motto: cultiv attitud gratitude. #vibe #tuesday #motiv #lawofattract
# Sentiment: negative, Text: thank be abl remember. #thank #posit
# Sentiment: negative, Text: ðð»ðð½ðð¿ðð¼ððð¼ð ð¼ðð ððððð ð#love#me#instagood#follow#photooftheday #tagsforlike#beautiful#selfie#gâ¦
# Sentiment: negative, Text: collect launch 25th june #bedford #aist #blueski
# Sentiment: negative, Text: offic that #jew offici eye #libtard masses?
# Sentiment: negative, Text: it' return #bone thursday
